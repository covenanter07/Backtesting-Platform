# %% [markdown]
# # 各資料讀取(技術面基本面)

# %%
from finlab.ml import fundamental_features
from finlab import data
import pandas as pd 
import ffn 

data = data.Data()



#基本面建置
monthly = {}
monthly["當月營收"] = data.get_adj('當月營收')
monthly["上月營收"] = data.get_adj('上月營收')
monthly["上月增減百分比"] = data.get_adj('上月比較增減(%)')
monthly["去年當月營收"] = data.get_adj('去年當月營收')
monthly["去年同月增減百分比"] = data.get_adj('去年同月增減(%)')
monthly["去年累計營收"] = data.get_adj('去年累計營收')
monthly["本益比"] = data.get_adj('本益比')
#monthly["本益比"].fillna(method = 'ffill',axis=1 ,limit=None).reindex(every_month)
monthly_fundamental = pd.DataFrame({name: df.unstack() for name, df in monthly.items()}) 

quarterly_fundamental = fundamental_features()

#技術面建置 (#開高低收建置(還原息))
close = data.get_adj('收盤價')
high = data.get_adj('最高價')
low = data.get_adj('最低價')
open = data.get_adj('開盤價')
volume = data.get('成交股數')
#各種指數建置

#籌碼面建置
#chip_analysis["外資買超"] = data.get('外陸資買進股數(不含外資自營商)') + data.get('外陸資買進股數(不含外資自營商)') 
#chip_analysis["外資賣超"] 

chip_analysis ={}
chip_analysis["自營商買賣超"] = data.get('自營商買賣超股數(自行買賣)') + data.get('自營商買賣超股數(避險)')
chip_analysis["投信買賣超"]= data.get('投信買賣超股數')

#回測時間
every_month = monthly_fundamental.index
every_quarter = quarterly_fundamental.index.get_level_values(1)
# Out:
# C:\Users\allen\AppData\Roaming\Python\Python39\site-packages\_distutils_hack\__init__.py:33: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")

# %% [markdown]
# ## for test use

# %%
import numpy as np
import pandas as pd
from talib import abstract
from finlab.data import Data
import ffn

# %matplotlib inline

data = Data()

signal = data.talib('CDLTRISTAR')

close = data.get_adj('收盤價')
open = data.get_adj('開盤價')

# %% [markdown]
# # 回測系統建置

# %%
###輸入回測對象
sids =['2330','0050','0015']
#start_time = '2012-01-01'
#end_time = '2020-12-2'


#signal = signal[sids]
#日期及回測對象前處理
if sids != []:
    close = close[sids]
    open_ = open_[sids]

if start_time or close_time :
    close = close[start_time : end_time]
    
#buy,sell需要自定義
buy = close > close.rolling(20).mean()
sell = close < close.rolling(20).mean()


#hold前處理
hold = pd.DataFrame(np.nan, index=close.index, columns=close.columns)
hold[buy] = 1
hold[sell] = 0
hold.ffill(inplace=True)
hold.fillna(0, inplace=True)
hold = hold.shift()

import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (10, 6)
hold.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# # 計算報酬率

# %%
import matplotlib.pyplot as plt

#gain = 明天開盤價 / 今天開盤價  得到單日報酬 (ffill補足未交易日，往上填充)
gain = open_.shift(-1).ffill() / open_.ffill()


#print(gain[hold == 1]['0050'])
#profit 取得gain報酬且hold = true , 資產分布平均加乘 (當天沒買進則填入1) 
#profit = 資產平均分布加乘
profit = (gain[hold == 1].mean(axis=1)).fillna(1).cumprod()

profit.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# # 股票變換時才變更部位

# %%
#得到股票更換總數量
rebalance = (hold.diff().abs().sum(axis=1) != 0).cumsum()

#得到股票變換日期
rebalance_hold = hold[rebalance.diff() != 0]

#得到股票變換日期報酬
rebalance_gain = gain.groupby(rebalance).apply(lambda s:s.cumprod().iloc[-1])
rebalance_gain.index = rebalance_hold.index



profit2 = (rebalance_gain[rebalance_hold == 1]).mean(axis=1).fillna(1).cumprod()

# %% [markdown]
# # 計算手續費報酬

# %%
#當同時有多項資產買進，資產平均分配
position_diff = rebalance_hold.div(rebalance_hold.sum(axis=1), axis=0)
##將nan部分補0，diff等等方便tax計算
position_diff = position_diff.fillna(0).diff()

#計算交易手續費
tax_ratio = position_diff.copy()
tax_ratio[tax_ratio < 0] *= (1.425/1000 + 3/1000)
tax_ratio[tax_ratio > 0] *= (1.425/1000)
##將買進手續費變成正數，並全部加總
tax_ratio = tax_ratio.abs().sum(axis=1)

###加上手續費報酬
profit_final = (rebalance_gain[rebalance_hold == 1].mean(axis=1).fillna(1) * (1 - tax_ratio)).cumprod()

all_profit = {}
all_profit['profit_final'] = profit_final

#獲得0050資料
twii = data.get_adj('收盤價')['0050'][start_time:end_time]
all_profit['0050'] = (twii.shift(-1)/twii.shift()).cumprod()
all_profit = pd.DataFrame(all_profit)
all_profit.plot()
profit_final.iloc[-1]

stats = profit_final.calc_stats()
stats.display()
# Out:
# Stats for None from 2012-01-02 00:00:00 - 2020-11-05 00:00:00
# Annual risk-free rate considered: 0.00%
# Summary:
# Total Return      Sharpe  CAGR    Max Drawdown
# --------------  --------  ------  --------------
# -47.59%            -1.12  -7.05%  -62.08%
#
# Annualized Returns:
# mtd    3m      6m      ytd    1y      3y      5y      10y    incep.
# -----  ------  ------  -----  ------  ------  ------  -----  --------
# 6.03%  -0.46%  16.31%  8.40%  11.03%  -2.26%  -1.82%  -      -7.05%
#
# Periodic:
#         daily    monthly    yearly
# ------  -------  ---------  --------
# sharpe  -1.12    -0.65      -0.34
# mean    -31.40%  -9.42%     -5.29%
# vol     28.09%   14.38%     15.51%
# skew    5.06     1.92       -0.48
# kurt    51.63    9.45       -0.23
# best    21.29%   21.33%     15.68%
# worst   -6.50%   -9.94%     -31.75%
#
# Drawdowns:
# max      avg        # days
# -------  -------  --------
# -62.08%  -16.44%    793.75
#
# Misc:
# ---------------  ------
# avg. up month    2.79%
# avg. down month  -3.14%
# up year %        37.50%
# 12m up %         11.46%
# ---------------  ------
